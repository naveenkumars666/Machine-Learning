# %%
#Add all the files in the same directory where python is available
import pandas as pd
import glob

path="C:/Users/Pravin Kumar/OneDrive/Desktop/dataset.zip" 
with open('my_file2.csv', 'w') as csv_file:
    #loop to read all txt  files and store in one csv file
    for path in glob.glob('./*.txt',):
        with open(path) as txt_file:
            txt = txt_file.read() + '\n'
            csv_file.write(txt)
df=pd.read_csv("my_file2.csv",header=None, names=["State","Gender","Year","Name","Frequency"])

# %%
df
# Out:
#         State Gender  Year      Name  Frequency
# 0          AK      F  1910      Mary         14
# 1          AK      F  1910     Annie         12
# 2          AK      F  1910      Anna         10
# 3          AK      F  1910  Margaret          8
# 4          AK      F  1910     Helen          7
# ...       ...    ...   ...       ...        ...
# 5551084    WY      M  2015  Sterling          5
# 5551085    WY      M  2015    Steven          5
# 5551086    WY      M  2015     Trace          5
# 5551087    WY      M  2015   Tristan          5
# 5551088    WY      M  2015     Tyson          5
#
# [5551089 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5551089 entries, 0 to 5551088
# Data columns (total 5 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   State      object
#  1   Gender     object
#  2   Year       int64
#  3   Name       object
#  4   Frequency  int64
# dtypes: int64(2), object(3)
# memory usage: 211.8+ MB

# %%
df.tail()
# Out:
#         State Gender  Year      Name  Frequency
# 5551084    WY      M  2015  Sterling          5
# 5551085    WY      M  2015    Steven          5
# 5551086    WY      M  2015     Trace          5
# 5551087    WY      M  2015   Tristan          5
# 5551088    WY      M  2015     Tyson          5

# %%
df.describe()
# Out:
#                Year     Frequency
# count  5.551089e+06  5.551089e+06
# mean   1.972798e+03  5.267360e+01
# std    2.987868e+01  1.808348e+02
# min    1.910000e+03  5.000000e+00
# 25%    1.950000e+03  7.000000e+00
# 50%    1.977000e+03  1.300000e+01
# 75%    1.999000e+03  3.400000e+01
# max    2.015000e+03  1.002300e+04

# %%
df.Gender.value_counts()
# Out:
# F    3096914
# M    2454175
# Name: Gender, dtype: int64

# %%
b=df.sort_values(by=["Frequency"],ascending=False)
b.head(10)
# Out:
#         State Gender  Year     Name  Frequency
# 3643958    NY      M  1947   Robert      10023
# 3643959    NY      M  1947     John       9636
# 3643253    NY      M  1946   Robert       9295
# 3658394    NY      M  1963  Michael       9251
# 3653272    NY      M  1958  Michael       9206
# 3647863    NY      M  1952   Robert       9204
# 3652310    NY      M  1957  Michael       9115
# 3648690    NY      M  1953   Robert       9069
# 3656323    NY      M  1961  Michael       9056
# 3647055    NY      M  1951   Robert       9053

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#plot a graph to know state wise frequency
plt.figure(figsize=(15,7))
plt.scatter(df.State,df.Frequency,alpha=0.6,color='purple')
plt.xlabel('State')
plt.ylabel('Frequency')
plt.title('State VS Frequency ')
# Out:
# Text(0.5, 1.0, 'State VS Frequency ')

# %%
#creating a crosstab /table of state vs gender
xtab = pd.crosstab(df['State'],df['Gender'])

# %%
#plot a bar graph for analysis
xtab.plot(kind='bar',stacked=True,figsize=(15,7),color=['Black','orange'],alpha=0.8)
plt.ylabel('Gender')
plt.title("State wise Gender count")
# Out:
# Text(0.5, 1.0, 'State wise Gender count')

# %%
plt.figure(figsize=(15,7))
plt.scatter(df.Year,df.Frequency,alpha=0.6,color='Blue')
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.title('Year VS Frequency ')
# Out:
# Text(0.5, 1.0, 'Year VS Frequency ')

# %%
#Top 10 Male Names
df_Male = df[df.Gender =='M']
df_Male2 = pd.DataFrame(df_Male.Name.value_counts()[:10]).reset_index()
df_Male2.columns = ['Name', 'Frequency']
df_Male2
# Out:
#       Name  Frequency
# 0     John       5300
# 1  William       5300
# 2    James       5299
# 3   Robert       5295
# 4  Charles       5292
# 5   Joseph       5291
# 6   Thomas       5276
# 7    David       5269
# 8  Richard       5253
# 9     Paul       5228

# %%
#Top 10 Female Names
df_Female = df[df.Gender =='F']
df_Female = pd.DataFrame(df_Female.Name.value_counts()[:10]).reset_index()
df_Female.columns = ['Name', 'Frequency']
df_Female
# Out:
#         Name  Frequency
# 0  Elizabeth       5277
# 1       Mary       5258
# 2       Anna       5209
# 3  Katherine       5203
# 4   Margaret       5166
# 5  Catherine       5097
# 6      Laura       5075
# 7      Sarah       5048
# 8      Julia       5022
# 9    Kathryn       5021
